# %% [markdown]
# ### Purpose of the Assignment:
#
# ##### Understand the factors affecting the demand for these shared bikes in the American market. The company wants to know:
#
# - Which variables are significant in predicting the demand for shared bikes.
# - How well those variables describe the bike demands
#
# ### Target Variable - 'cnt'

# %% [markdown]
# ### Database Dictionary for reference:
#
# 	- instant: record index
# 	- dteday : date
# 	- season : season (1:spring, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2018, 1:2019)
# 	- mnth : month ( 1 to 12)
# 	- holiday : weather day is a holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : temperature in Celsius
# 	- atemp: feeling temperature in Celsius
# 	- hum: humidity
# 	- windspeed: wind speed
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# # Importing necessary libraries

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Libraries for Visualisation 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Libaries for linear Regression

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm

from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# # Reading the dataset

# %%
bikedata= pd.read_csv("D:\Certificate courses\Data Science\Bike Sharing Assignment\day.csv")
bikedata.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ## Step 1: Understanding the Data

# %%
bikedata.shape
# Out:
# (730, 16)

# %%
bikedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
bikedata.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %% [markdown]
# ### Step Taken:
#
# - Columns such as casual and registered customers are included in 'cnt'; therefore, I have chosen to drop the two columns from the dataset.
# - I have also chosen to drop the date column as the data set includes seperate columns for year, month, holidays & workdays.

# %%
# dropping unnecessary columns

bikedata.drop(['instant'], axis = 1, inplace = True)
bikedata.drop(['casual'], axis = 1, inplace = True)
bikedata.drop(['registered'], axis = 1, inplace = True)
bikedata.drop(['dteday'], axis = 1, inplace = True)

# %%
# Columns in dataset after dropping

bikedata.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        1           1           2  14.110847
# 1       1   0     1        0        2           1           2  14.902598
# 2       1   0     1        0        3           1           1   8.050924
# 3       1   0     1        0        4           1           1   8.200000
# 4       1   0     1        0        5           1           1   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %% [markdown]
# ## Step 2: Visualising the Data

# %% [markdown]
# ### Visualising Numeric Variables

# %%
plt.figure(figsize = (16, 10))
sns.heatmap(bikedata.corr(), cmap="YlGnBu", annot = True)
plt.show()

# %% [markdown]
# ### Visualising Categorical Variables

# %%
fig, axes = plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(20, 20)

sns.boxplot(data=bikedata,y="cnt",x="season",orient="v",ax=axes[0][0])
sns.boxplot(data=bikedata,y="cnt",x="yr",orient="v",ax=axes[0][1])
sns.boxplot(data=bikedata,y="cnt",x="mnth",orient="v",ax=axes[1][0])
sns.boxplot(data=bikedata,y="cnt",x="holiday",orient="v",ax=axes[1][1])
sns.boxplot(data=bikedata,y="cnt",x="workingday",orient="v",ax=axes[2][0])
sns.boxplot(data=bikedata,y="cnt",x="weekday",orient="v",ax=axes[2][1])
sns.boxplot(data=bikedata,y="cnt",x="weathersit",orient="v",ax=axes[3][0])
sns.boxplot(bikedata.cnt, orient="v",ax=axes[3][1])

axes[0][0].set(xlabel='Season', ylabel='Count',title="Box Plot On Count Across Seasons")
axes[0][1].set(xlabel='Year', ylabel='Count',title="Box Plot On Count in the year 2018 & 2019")
axes[1][0].set(xlabel='Month', ylabel='Count',title="Box Plot On Count Across all months")
axes[1][1].set(xlabel='Holiday', ylabel='Count',title="Box Plot On Count on Holidays")
axes[2][0].set(xlabel='Working Day', ylabel='Count',title="Box Plot On Count Across Working Day")
axes[2][1].set(xlabel='Week Day', ylabel='Count',title="Box Plot On Count Across Weekdays")
axes[3][0].set(xlabel='Weather Situation', ylabel='Count',title="Box Plot On Count Across Weather Situations")
axes[3][1].set(xlabel='Count',title="Distribution Of Count")
plt.show()

# %% [markdown]
# ## Step 3: Data Preparation

# %% [markdown]
# ### Step Taken: The variable 'weathersit' has four levels. We need to convert these levels into integer as well. For this, I will use something called `dummy variables`.

# %%
# Dummy Variable- 'Weathersit'
Weathersit= pd.get_dummies(bikedata['weathersit'], drop_first = True)

# Renaming '2' and '3' columns to 'Mist' and 'light Snow'
Weathersit.columns= ['Mist', 'Light Snow']

# %%
# Check what the dataset'Weathersit' looks like
Weathersit.head()
# Out:
#    Mist  Light Snow
# 0     1           0
# 1     1           0
# 2     0           0
# 3     0           0
# 4     0           0

# %%
# Combine both datasets

bikedata = pd.concat([bikedata, Weathersit], axis = 1)

# %%
# Drop 'weathersit' as we have created the dummies for it

bikedata.drop(['weathersit'], axis = 1, inplace = True)

# %%
bikedata.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday       temp     atemp  \
# 0       1   0     1        0        1           1  14.110847  18.18125
# 1       1   0     1        0        2           1  14.902598  17.68695
# 2       1   0     1        0        3           1   8.050924   9.47025
# 3       1   0     1        0        4           1   8.200000  10.60610
# 4       1   0     1        0        5           1   9.305237  11.46350
#
#        hum  windspeed   cnt  Mist  Light Snow
# 0  80.5833  10.749882   985     1           0
# 1  69.6087  16.652113   801     1           0
# 2  43.7273  16.636703  1349     0           0
# 3  59.0435  10.739832  1562     0           0
# 4  43.6957  12.522300  1600     0           0

# %% [markdown]
# ### Visualizing numerical variable for the final dataset

# %%
sns.pairplot(bikedata, x_vars=["temp", "atemp", "hum", 'windspeed', 'cnt'], y_vars=["temp", "atemp", "hum", 'windspeed', 'cnt'],)
plt.show()

# %% [markdown]
# ## Step 4: Splitting the Data into Training and Testing Sets

# %% [markdown]
# ### Step Taken: As you know, the first basic step for regression is performing a train-test split.

# %%
df_train, df_test = train_test_split(bikedata, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
print(df_train.shape)
# Out:
# (510, 13)

# %%
print(df_test.shape)
# Out:
# (219, 13)

# %% [markdown]
# ## Step 5: Rescaling the Features

# %%
scaler = MinMaxScaler()
num_vars = ['temp', 'atemp','hum', 'windspeed', 'cnt']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#      season  yr  mnth  holiday  weekday  workingday      temp     atemp  \
# 653       4   1    10        0        3           1  0.509887  0.501133
# 576       3   1     7        0        3           1  0.815169  0.766351
# 426       1   1     3        0        0           0  0.442393  0.438975
# 728       1   1    12        0        1           1  0.245101  0.200348
# 482       2   1     4        0        0           0  0.395666  0.391735
#
#           hum  windspeed       cnt  Mist  Light Snow
# 653  0.575354   0.300794  0.864243     0           0
# 576  0.725633   0.264686  0.827658     0           0
# 426  0.640189   0.255342  0.465255     1           0
# 728  0.498067   0.663106  0.204096     0           0
# 482  0.504508   0.188475  0.482973     1           0

# %%
df_train.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     2.517647    0.507843    6.549020    0.025490    2.950980    0.711765
# std      1.111947    0.500429    3.468714    0.157763    1.977166    0.453386
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    3.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#              temp       atemp         hum   windspeed         cnt        Mist  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.537262    0.512989    0.650369    0.320768    0.513620    0.343137
# ...

# %%
# Let's check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### Step Taken: Checking correlation between column 'temp' and 'atemp' and dropping one if correlation is high.

# %%
# Drop 'atemp' as we have a highly correlated column of 'temp'

df_train.drop(['atemp'], axis = 1, inplace = True)

# %%
# Final test dataset

df_train.head()
# Out:
#      season  yr  mnth  holiday  weekday  workingday      temp       hum  \
# 653       4   1    10        0        3           1  0.509887  0.575354
# 576       3   1     7        0        3           1  0.815169  0.725633
# 426       1   1     3        0        0           0  0.442393  0.640189
# 728       1   1    12        0        1           1  0.245101  0.498067
# 482       2   1     4        0        0           0  0.395666  0.504508
#
#      windspeed       cnt  Mist  Light Snow
# 653   0.300794  0.864243     0           0
# 576   0.264686  0.827658     0           0
# 426   0.255342  0.465255     1           0
# 728   0.663106  0.204096     0           0
# 482   0.188475  0.482973     1           0

# %% [markdown]
# ### Step Taken: Dividing into X and Y sets for the model building

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %% [markdown]
# ## Step 6: Building a linear model

# %% [markdown]
# #### Model 1:

# %%
# Add a constant
X_train_lm = sm.add_constant(X_train[['temp']])

# Create a first fitted model
lr = sm.OLS(y_train, X_train_lm).fit()

# %%
# Check the parameters obtained

lr.params
# Out:
# const    0.169798
# temp     0.639952
# dtype: float64

# %%
# Let's visualise the data with a scatter plot and the fitted regression line

plt.scatter(X_train_lm.iloc[:, 1], y_train)
plt.plot(X_train_lm.iloc[:, 1], 0.169 + 0.639*X_train_lm.iloc[:, 1], 'r')
plt.show()

# %%
# Print a summary of the linear regression model obtained
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.414
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     359.1
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):           5.80e-61
# Time:                        22:58:03   Log-Likelihood:                 174.84
# No. Observations:                 510   AIC:                            -345.7
# Df Residuals:                     508   BIC:                            -337.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1698      0.020      8.628      0.000       0.131       0.208
# ...

# %% [markdown]
# ### Step Taken: Adding another variable - The R-squared value obtained is `0.414`. Since the dataset has other variables, we keep adding the next highly correlated variable, i.e. `Yr`/ Year.

# %% [markdown]
# #### Model 2:

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'yr']]

# %%
X_train_lm = sm.add_constant(X_train_lm)

lr_2 = sm.OLS(y_train, X_train_lm).fit()

lr_2.params
# Out:
# const    0.079628
# temp     0.583559
# yr       0.237213
# dtype: float64

# %%
# Check the summary
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     564.9
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          9.25e-130
# Time:                        22:58:03   Log-Likelihood:                 337.38
# No. Observations:                 510   AIC:                            -668.8
# Df Residuals:                     507   BIC:                            -656.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0796      0.015      5.331      0.000       0.050       0.109
# ...

# %% [markdown]
# ### Step Taken: We have clearly improved the model as the value of R-squared has gone up to 0.69 from 0.414. Let's go ahead and add another variable, 'season'.

# %% [markdown]
# #### Model 3:

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'yr', 'season']]

# %%
# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr_3 = sm.OLS(y_train, X_train_lm).fit()

lr_3.params
# Out:
# const     0.009938
# temp      0.515487
# yr        0.239221
# season    0.041802
# dtype: float64

# %%
# Print the summary of the model

print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     452.5
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          8.85e-143
# Time:                        22:58:03   Log-Likelihood:                 370.94
# No. Observations:                 510   AIC:                            -733.9
# Df Residuals:                     506   BIC:                            -716.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0099      0.016      0.611      0.541      -0.022       0.042
# ...

# %% [markdown]
# ### Step Taken: We have improved the value R-squared again. Now keep adding all the feature variables.

# %% [markdown]
# #### Model 4:

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'yr', 'season', 'hum']]

# %%
# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr_4 = sm.OLS(y_train, X_train_lm).fit()

lr_4.params
# Out:
# const     0.142937
# temp      0.530975
# yr        0.232468
# season    0.047828
# hum      -0.235347
# dtype: float64

# %%
# Print the summary of the model

print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                     379.2
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.45e-150
# Time:                        22:58:03   Log-Likelihood:                 392.24
# No. Observations:                 510   AIC:                            -774.5
# Df Residuals:                     505   BIC:                            -753.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1429      0.025      5.626      0.000       0.093       0.193
# ...

# %% [markdown]
# ### Step Taken: We have improved the value R-squared once again. Here the coefficient of 'Humidity' is negative and all P-values are 0 which means we have a strong model so far.

# %% [markdown]
# #### Model 5:

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'yr', 'season', 'hum', 'windspeed']]

# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr_5 = sm.OLS(y_train, X_train_lm).fit()

lr_5.params
# Out:
# const        0.266186
# temp         0.513619
# yr           0.232019
# season       0.043590
# hum         -0.289578
# windspeed   -0.211229
# dtype: float64

# %%
# Print the summary of the model

print(lr_5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     343.2
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.11e-159
# Time:                        22:58:04   Log-Likelihood:                 416.60
# No. Observations:                 510   AIC:                            -821.2
# Df Residuals:                     504   BIC:                            -795.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2662      0.030      8.929      0.000       0.208       0.325
# ...

# %% [markdown]
# ### Step taken: We have improved the adjusted R-squared again. Now let's go ahead and add all the feature variables.

# %% [markdown]
# #### Model 6:

# %%
# Assign all the feature variables to X
X_train_lm = X_train[['temp', 'yr', 'season', 'hum', 'windspeed', 'holiday', 'mnth','weekday', 'workingday','Mist', 'Light Snow']]

# Build a linear model

import statsmodels.api as sm
X_train_lm = sm.add_constant(X_train_lm)

lr_6 = sm.OLS(y_train, X_train_lm).fit()

lr_6.params
# Out:
# const         0.178382
# temp          0.474714
# yr            0.231617
# season        0.050128
# hum          -0.110397
# windspeed    -0.155778
# holiday      -0.107431
# mnth         -0.001438
# weekday       0.003185
# workingday   -0.017473
# Mist         -0.056034
# Light Snow   -0.253392
# dtype: float64

# %%
# Print the summary of the model

print(lr_6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     190.6
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.57e-170
# Time:                        22:58:04   Log-Likelihood:                 459.36
# No. Observations:                 510   AIC:                            -894.7
# Df Residuals:                     498   BIC:                            -843.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1784      0.031      5.699      0.000       0.117       0.240
# ...

# %% [markdown]
# ### Step Taken: We generally want a VIF that is less than 5. So there are clearly some variables we need to drop.
#
# - High P-value and High VIF definitely needs to be dropped.
# - High P-value and Low VIF also needs to be dropped.

# %%
# Create a dataframe that will contain the names of all the feature variables and their respective VIFs
vif = pd.DataFrame()
vif['Features'] = X_train.columns
vif['VIF'] = [variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#       Features    VIF
# 0       season  23.81
# 7          hum  18.09
# 2         mnth  17.06
# 6         temp   8.01
# 5   workingday   3.64
# 8    windspeed   3.57
# 4      weekday   3.10
# 9         Mist   2.19
# 1           yr   2.02
# 10  Light Snow   1.17
# 3      holiday   1.11

# %% [markdown]
# ### StepTaken: Dropping the variable and updating the model
#
# - As you can see from the summary and the VIF dataframe, some variables are still insignificant. One of these variables is, `Mnth` as it has a very high p-value of `0.559`. Let's go ahead and drop this variables

# %% [markdown]
# #### Model 7:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop('mnth', 1,)

# %%
# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_7 = sm.OLS(y_train, X_train_lm).fit()

# %%
# Print the summary of the model
print(lr_7.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     209.9
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.25e-171
# Time:                        22:58:04   Log-Likelihood:                 459.19
# No. Observations:                 510   AIC:                            -896.4
# Df Residuals:                     499   BIC:                            -849.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1793      0.031      5.739      0.000       0.118       0.241
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 6         hum  17.91
# 5        temp   7.92
# 0      season   7.13
# 4  workingday   3.64
# 7   windspeed   3.57
# 3     weekday   3.10
# 8        Mist   2.18
# 1          yr   2.01
# 9  Light Snow   1.17
# 2     holiday   1.11

# %% [markdown]
# ### Step Taken: Dropping the variable and updating the model
#
# - Dropping `mnth` decreased the P-value of most of the variables. But from the summary, we can still see some of them have a high p-value. `Weekday` for instance, has a p-value of 0.156. We should drop this variable as well.

# %% [markdown]
# #### Model 8:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop(['mnth','weekday'], 1,)

# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_8 = sm.OLS(y_train, X_train_lm).fit()

# Print the summary of the model
print(lr_8.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.804
# Method:                 Least Squares   F-statistic:                     232.5
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          2.18e-172
# Time:                        22:58:04   Log-Likelihood:                 458.16
# No. Observations:                 510   AIC:                            -896.3
# Df Residuals:                     500   BIC:                            -854.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1889      0.031      6.188      0.000       0.129       0.249
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 5         hum  16.81
# 4        temp   7.88
# 0      season   7.13
# 3  workingday   3.62
# 6   windspeed   3.53
# 7        Mist   2.17
# 1          yr   2.01
# 8  Light Snow   1.17
# 2     holiday   1.11

# %% [markdown]
# ### Step Taken: Dropping the variable and updating the model
#
# - `Workingday` for instance, has a p-value of 0.093. We should drop this variable as well.

# %% [markdown]
# #### Model 9:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop(['mnth','weekday','workingday'], 1,)

# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_9 = sm.OLS(y_train, X_train_lm).fit()

# Print the summary of the model
print(lr_9.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.806
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     260.2
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          5.33e-173
# Time:                        22:58:04   Log-Likelihood:                 456.72
# No. Observations:                 510   AIC:                            -895.4
# Df Residuals:                     501   BIC:                            -857.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1789      0.030      5.964      0.000       0.120       0.238
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 4         hum  14.85
# 3        temp   7.88
# 0      season   7.10
# 5   windspeed   3.43
# 6        Mist   2.10
# 1          yr   2.01
# 7  Light Snow   1.15
# 2     holiday   1.03

# %% [markdown]
# ### Step Taken: Dropping the variable and updating the model
#
# - Here, all variable have acceptable levels of P-values, but variable `Hum` for instance, has a VIF of 14.85. We should drop this variable as well now.

# %% [markdown]
# #### Model 10:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop(['mnth','weekday','workingday', 'hum'], 1,)

# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_10 = sm.OLS(y_train, X_train_lm).fit()

# Print the summary of the model
print(lr_10.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.800
# Method:                 Least Squares   F-statistic:                     291.9
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.86e-172
# Time:                        22:58:04   Log-Likelihood:                 452.51
# No. Observations:                 510   AIC:                            -889.0
# Df Residuals:                     502   BIC:                            -855.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1114      0.019      5.885      0.000       0.074       0.149
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features   VIF
# 3        temp  5.99
# 0      season  5.65
# 4   windspeed  2.95
# 1          yr  2.00
# 5        Mist  1.47
# 6  Light Snow  1.08
# 2     holiday  1.03

# %% [markdown]
# ### Step Taken: Dropping the variable and updating the model
#
# - Here, all variable have acceptable levels of P-values, but variable `temp` has a relatively high VIF of temp 5.99. We should check the R-squared by dropping this variable.

# %% [markdown]
# #### Model 11:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop(['mnth','weekday','workingday','hum','temp'], 1,)

# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_11 = sm.OLS(y_train, X_train_lm).fit()

# Print the summary of the model
print(lr_11.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.614
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     133.5
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          1.12e-100
# Time:                        22:58:04   Log-Likelihood:                 281.40
# No. Observations:                 510   AIC:                            -548.8
# Df Residuals:                     503   BIC:                            -519.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3123      0.023     13.503      0.000       0.267       0.358
# ...

# %% [markdown]
# ### Step Taken: Here by dropping the variable 'Temp', the R-squared significantly decreases from  0.803 to 0.614. So we consider this variable as a significant predictor variable.
#
# ### We go ahead and try dropping variable 'holiday' and check the significance.

# %% [markdown]
# #### Model 12:

# %%
# Dropping highly correlated variables and insignificant variables

X = X_train.drop(['mnth','weekday','workingday','hum','holiday'], 1,)

# Build a fitted model after dropping
X_train_lm = sm.add_constant(X)

lr_12 = sm.OLS(y_train, X_train_lm).fit()

# Print the summary of the model
print(lr_12.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    cnt   R-squared:                       0.798
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     331.7
# Date:                Mon, 08 Mar 2021   Prob (F-statistic):          2.90e-171
# Time:                        22:58:04   Log-Likelihood:                 446.71
# No. Observations:                 510   AIC:                            -879.4
# Df Residuals:                     503   BIC:                            -849.8
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1067      0.019      5.598      0.000       0.069       0.144
# ...

# %%
# Calculate the VIFs again for the new model

vif = pd.DataFrame()
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features   VIF
# 2        temp  5.98
# 0      season  5.62
# 3   windspeed  2.93
# 1          yr  2.00
# 4        Mist  1.47
# 5  Light Snow  1.08

# %% [markdown]
# ### Step Taken: So we go ahead with Model 12 to make our predictions as the value R-squared has not changed much.

# %% [markdown]
# ## Step 7: Residual Analysis of the train data

# %% [markdown]
# ### Step Taken: So, now to check if the error terms are also normally distributed.

# %%
y_train_cnt = lr_12.predict(X_train_lm)

# %%
# Plot the histogram of the error terms
fig = plt.figure()
sns.distplot((y_train - y_train_cnt), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                
plt.xlabel('Errors', fontsize = 18)    
plt.show()

# %% [markdown]
# #### The error terms are normally distributed.

# %% [markdown]
# ## Step 8: Making Predictions Using the Final Model

# %% [markdown]
# ### Step Taken: Now that we have fitted the model and checked the normality of error terms, it's time to go ahead and make predictions using the final, i.e. 12th model.

# %% [markdown]
# #### Applying the scaling and other modifications on the test sets

# %%
num_vars = ['temp', 'atemp','hum', 'windspeed', 'cnt']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test.describe()
# Out:
#            season          yr        mnth     holiday     weekday  workingday  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     2.456621    0.479452    6.474886    0.036530    3.100457    0.639269
# std      1.109463    0.500722    3.421875    0.188034    2.058536    0.481313
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      2.000000    0.000000    6.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000    9.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#              temp       atemp         hum   windspeed         cnt        Mist  \
# count  219.000000  219.000000  219.000000  219.000000  219.000000  219.000000
# mean     0.558941    0.532991    0.638508    0.313350    0.520592    0.319635
# ...

# %%
# Drop 'atemp' as we have a highly correlated column of 'temp' in the test set

df_test.drop(['atemp'], axis = 1, inplace = True)

# %%
#### Dividing into X_test and y_test

y_test = df_test.pop('cnt')
X_test = df_test

# %%
# Adding constant variable to test dataframe
X_test_m12 = sm.add_constant(X_test)

# %%
# Creating X_test_m12 dataframe by dropping variables from X_test_m12 as per train set

X_test_m12 = X_test_m12.drop(['mnth','weekday','workingday','hum','holiday'], axis = 1)

# %%
# Making predictions using the 12th model

y_pred_m12 = lr_12.predict(X_test_m12)

# %% [markdown]
# ## Step 9: Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred_m12)
fig.suptitle('y_test vs y_pred', fontsize = 20)               
plt.xlabel('y_test', fontsize = 18)                          
plt.ylabel('y_pred', fontsize = 16)      
plt.show()

# %% [markdown]
# ### Step Taken: Using R-squared for evaluating the model on the test set.

# %%
r2_score(y_test, y_pred_m12)
# Out:
# 0.7747979946725332
